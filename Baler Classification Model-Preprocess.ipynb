# %% [markdown]
# # Import libraries

# %%
import datetime
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sqlalchemy as sa

# %matplotlib inline

# %% [markdown]
# # Get the Dataset

# %%
sql_con_str = 'mysql+mysqldb://mercenary:Flxi8571@40.69.142.165:3306/Sustayn'  # NST02 / PROD
ENGINE = sa.create_engine(sql_con_str, pool_recycle = 3600)

# Stract the data from the Database
SQL = """
SELECT * 
FROM sustayn.v_ml_baler_productor_history
WHERE audit_date IS NULL
UNION
SELECT DeviceType, Null, Null, max(package_date), device_id, Null, Null, Null, Null, NUll, Null, NUll, 'KG', 'A', Null, Null
FROM sustayn.v_ml_baler_productor_history
WHERE audit_date IS NOT NULL
GROUP BY DeviceType, device_id;
"""

# read data from db to DataFrame
df = pd.read_sql_query(SQL, ENGINE)
#df.to_csv('data_frame-predict.csv')
df.shape
# Out:
# (262, 16)

# %% [markdown]
# # Analyse Dataset

# %%
df = pd.read_csv('data_frame-predict.csv')

# %%
# filling the missing values
df.fillna(0, inplace=True)

# %%
df.head(3).T
# Out:
#                                                                        0  \
# Unnamed: 0                                                             0
# DeviceType                                                         Baler
# id                                  014dac81-12ab-499f-9c69-adaa43409e44
# img_url                             014dac81-12ab-499f-9c69-adaa43409e44
# package_date                                             6/19/2020 20:53
# device_id                           b9e48ef9-1a7b-41c2-bad4-3c70ac2b14e9
# DeviceCode                                                      LEYM1010
# package_id                                                          1154
# barcode                                                                0
# material_type                                                          A
# material_description_from_original                                CARTON
# ir_original_class                                        BALED CARDBOARD
# net_weight                                                            98
# unit                                                                  KG
# audit_status                                                           0
# audit_date                                                             0
# audit_userid                                                           0
#
#                                                                        1  \
# Unnamed: 0                                                             1
# DeviceType                                                         Baler
# id                                  06689642-d633-4d30-a7a0-6e7711190362
# img_url                             06689642-d633-4d30-a7a0-6e7711190362
# package_date                                             6/26/2020 15:39
# device_id                           175ded97-27a5-4c71-b084-2dccaa759b8c
# DeviceCode                                                      SYSC1002
# package_id                                                            86
# barcode                                     SYSC10022006260A064006400086
# material_type                                                          A
# material_description_from_original                             OCC BALED
# ir_original_class                                                      0
# net_weight                                                           640
# unit                                                                  LB
# audit_status                                                           0
# audit_date                                                             0
# audit_userid                                                           0
#
#                                                                        2
# Unnamed: 0                                                             2
# DeviceType                                                         Baler
# id                                  09002e5e-6596-4dc4-9e3b-9f86d155f4cd
# img_url                             09002e5e-6596-4dc4-9e3b-9f86d155f4cd
# package_date                                             6/26/2020 14:50
# device_id                           fc7dacf9-8960-4a88-b4a9-02c36b6df9e0
# DeviceCode                                                      HEMM1008
# package_id                                                           997
# barcode                                     HEMM10082006260A023102310997
# material_type                                                          A
# material_description_from_original                                CARTON
# ir_original_class                                        BALED CARDBOARD
# net_weight                                                           231
# unit                                                                  KG
# audit_status                                                           0
# audit_date                                                             0
# audit_userid                                                           0

# %%
# sort dataframe by device_code and package_date
df.sort_values(by=['device_id','package_date'], ascending=[True, True], inplace=True, )

# %%
# reset index with the new order
df.reset_index(inplace=True, drop=True)

# %%
df.head(3)
# Out:
#    Unnamed: 0 DeviceType id img_url     package_date  \
# 0          85      Baler  0       0   6/15/2019 9:25
# 1          86      Baler  0       0  5/11/2020 18:18
# 2          87      Baler  0       0  6/25/2020 13:33
#
#                               device_id DeviceCode  package_id barcode  \
# 0  02467072-ffd6-432e-ab02-97e477ee3f94          0         0.0       0
# 1  039309c9-b9e6-4ca9-ada9-f52937087a79          0         0.0       0
# 2  04152770-fbc7-41a8-9b61-b19eaf55dc8f          0         0.0       0
#
#   material_type material_description_from_original ir_original_class  \
# 0             0                                  0                 0
# 1             0                                  0                 0
# 2             0                                  0                 0
#
#    net_weight unit audit_status  audit_date  audit_userid
# 0         0.0   KG            A         0.0           0.0
# 1         0.0   KG            A         0.0           0.0
# 2         0.0   KG            A         0.0           0.0

# %% [markdown]
# # Create extra labels

# %% [markdown]
# ## material_description_from_original

# %%
df['material_description_from_original'].value_counts()
# Out:
# 0            178
# CARTON        54
# OCC BALED     10
# FILM           9
# PLAYO          5
# OCC            4
# LLD FILM       2
# Name: material_description_from_original, dtype: int64

# %%
df['material_description_from_original'].unique()
# Out:
# array([0, 'PLAYO', 'CARTON', 'OCC', 'OCC BALED', 'FILM', 'LLD FILM'],
#       dtype=object)

# %%
# Redefine MaterialDescription to group in 3 categories fewer categories
def material_description(material):
    
    if 'OCC' in material:
        return 'BALED CARDBOARD'
    elif 'CARTON' in material:
        return 'BALED CARDBOARD'
    elif 'CARDBOARD' in material:
        return 'BALED CARDBOARD'
        
    elif 'FILM' in material:
        return 'BALED FILM'
    elif 'LDP' in material:
        return 'BALED FILM'
    elif 'PLAYO' in material:
        return 'BALED FILM'
    elif material == 'PLMX':
        return 'BALED FILM'
    elif material == 'SHRINK WRAP':
        return 'BALED FILM'
    elif material == 'BOMA':
        return 'BALED FILM'
    
    else:
        return 'BALED EMPTY'

# %%
df['material_description_f'] = df['material_description_from_original'].astype(str).str.upper().apply(material_description)

# %%
df['material_description_f'].value_counts()
# Out:
# BALED EMPTY        178
# BALED CARDBOARD     68
# BALED FILM          16
# Name: material_description_f, dtype: int64

# %% [markdown]
# ## package_date

# %%
# create a new field from the package_date but truncating the secs
df['package_date']   = df['package_date'].astype('datetime64')
df['package_date_f'] = df['package_date'].dt.strftime("%m/%d/%Y %H:%M").astype('datetime64')

# %%
# Creata a time interval delta
def diff_func(df):
    return abs(df.diff().dt.total_seconds() / 60)

# Now call the function using .apply
df['time_delta_f'] = df.groupby(['device_id'])['package_date'].apply(diff_func)

# Fill in any NaN values
df['time_delta_f'].fillna('0', inplace=True)

# Convert the output into a float
df['time_delta_f'] = pd.to_numeric(df['time_delta_f']).astype(int)

# %% [markdown]
# ## standard_weight

# %%
df['unit'].value_counts()
# Out:
# KG    237
# LB     25
# Name: unit, dtype: int64

# %%
# Standardize all the weights by making everything KGs
def standard_weight(row):
    if row['unit'] == 'LB':
        return round(row['net_weight'] * 0.453592 , 0)
    else:
        return row['net_weight']
    
df['standard_weight_f'] = df.apply(standard_weight, axis =1).astype(int)

# %%
df.loc[df['unit'] == 'LB' , ['unit','net_weight','standard_weight_f']].head(3)
# Out:
#    unit  net_weight  standard_weight_f
# 15   LB      1035.0                469
# 17   LB       642.0                291
# 18   LB       628.0                285

# %%
df.head(10).T
# Out:
#                                                                        0  \
# Unnamed: 0                                                            85
# DeviceType                                                         Baler
# id                                                                     0
# img_url                                                                0
# package_date                                         2019-06-15 09:25:00
# device_id                           02467072-ffd6-432e-ab02-97e477ee3f94
# DeviceCode                                                             0
# package_id                                                             0
# barcode                                                                0
# material_type                                                          0
# material_description_from_original                                     0
# ir_original_class                                                      0
# net_weight                                                             0
# unit                                                                  KG
# audit_status                                                           A
# audit_date                                                             0
# audit_userid                                                           0
# material_description_f                                       BALED EMPTY
# package_date_f                                       2019-06-15 09:25:00
# time_delta_f                                                           0
# standard_weight_f                                                      0
#
#                                                                        1  \
# Unnamed: 0                                                            86
# DeviceType                                                         Baler
# id                                                                     0
# img_url                                                                0
# package_date                                         2020-05-11 18:18:00
# device_id                           039309c9-b9e6-4ca9-ada9-f52937087a79
# DeviceCode                                                             0
# package_id                                                             0
# barcode                                                                0
# material_type                                                          0
# material_description_from_original                                     0
# ir_original_class                                                      0
# net_weight                                                             0
# unit                                                                  KG
# audit_status                                                           A
# audit_date                                                             0
# audit_userid                                                           0
# material_description_f                                       BALED EMPTY
# package_date_f                                       2020-05-11 18:18:00
# time_delta_f                                                           0
# standard_weight_f                                                      0
#
#                                                                        2  \
# Unnamed: 0                                                            87
# DeviceType                                                         Baler
# id                                                                     0
# img_url                                                                0
# package_date                                         2020-06-25 13:33:00
# device_id                           04152770-fbc7-41a8-9b61-b19eaf55dc8f
# DeviceCode                                                             0
# package_id                                                             0
# barcode                                                                0
# material_type                                                          0
# material_description_from_original                                     0
# ir_original_class                                                      0
# net_weight                                                             0
# unit                                                                  KG
# audit_status                                                           A
# audit_date                                                             0
# audit_userid                                                           0
# material_description_f                                       BALED EMPTY
# package_date_f                                       2020-06-25 13:33:00
# time_delta_f                                                           0
# standard_weight_f                                                      0
#
#                                                                        3  \
# Unnamed: 0                                                            28
# DeviceType                                                         Baler
# id                                  56016431-4754-4155-a88e-34025a996b0a
# img_url                             56016431-4754-4155-a88e-34025a996b0a
# package_date                                         2020-06-26 10:39:00
# device_id                           04152770-fbc7-41a8-9b61-b19eaf55dc8f
# DeviceCode                                                      WALM1018
# package_id                                                           604
# barcode                                     WALM10182006260B011201120604
# material_type                                                          B
# material_description_from_original                                 PLAYO
# ir_original_class                                             BALED FILM
# net_weight                                                           112
# unit                                                                  KG
# audit_status                                                           0
# audit_date                                                             0
# audit_userid                                                           0
# material_description_f                                        BALED FILM
# package_date_f                                       2020-06-26 10:39:00
# time_delta_f                                                        1266
# standard_weight_f                                                    112
#
#                                                                        4  \
# Unnamed: 0                                                            83
# DeviceType                                                         Baler
# id                                  fe5cddc7-303e-4a04-a909-337cc23e9f23
# img_url                             fe5cddc7-303e-4a04-a909-337cc23e9f23
# package_date                                         2020-06-26 09:50:00
# device_id                           04152770-fbc7-41a8-9b61-b19eaf55dc8f
# DeviceCode                                                      WALM1018
# package_id                                                           603
# barcode                                     WALM10182006260A035903590603
# material_type                                                          A
# material_description_from_original                                CARTON
# ir_original_class                                        BALED CARDBOARD
# net_weight                                                           359
# unit                                                                  KG
# audit_status                                                           0
# audit_date                                                             0
# audit_userid                                                           0
# material_description_f                                   BALED CARDBOARD
# package_date_f                                       2020-06-26 09:50:00
# time_delta_f                                                          49
# standard_weight_f                                                    359
#
#                                                                        5  \
# Unnamed: 0                                                            88
# DeviceType                                                         Baler
# id                                                                     0
# img_url                                                                0
# package_date                                         2020-06-25 09:28:00
# device_id                           09d09144-5db2-4461-8706-2f74b06e52b8
# DeviceCode                                                             0
# package_id                                                             0
# barcode                                                                0
# material_type                                                          0
# material_description_from_original                                     0
# ir_original_class                                                      0
# net_weight                                                             0
# unit                                                                  KG
# audit_status                                                           A
# audit_date                                                             0
# audit_userid                                                           0
# material_description_f                                       BALED EMPTY
# package_date_f                                       2020-06-25 09:28:00
# time_delta_f                                                           0
# standard_weight_f                                                      0
#
#                                                                        6  \
# Unnamed: 0                                                            23
# DeviceType                                                         Baler
# id                                  48fa2e14-0fde-4b83-99c6-592287781f1b
# img_url                             48fa2e14-0fde-4b83-99c6-592287781f1b
# package_date                                         2020-06-26 11:15:00
# device_id                           09d09144-5db2-4461-8706-2f74b06e52b8
# DeviceCode                                                      LEYM1008
# package_id                                                           539
# barcode                                                                0
# material_type                                                          A
# material_description_from_original                                CARTON
# ir_original_class                                        BALED CARDBOARD
# net_weight                                                           256
# unit                                                                  KG
# audit_status                                                           0
# audit_date                                                             0
# audit_userid                                                           0
# material_description_f                                   BALED CARDBOARD
# package_date_f                                       2020-06-26 11:15:00
# time_delta_f                                                        1547
# standard_weight_f                                                    256
#
#                                                                        7  \
# Unnamed: 0                                                            89
# DeviceType                                                         Baler
# id                                                                     0
# img_url                                                                0
# package_date                                         2019-05-31 15:34:00
# device_id                           0ae4190d-6acb-463d-857d-aab765f4554b
# DeviceCode                                                             0
# package_id                                                             0
# barcode                                                                0
# material_type                                                          0
# material_description_from_original                                     0
# ir_original_class                                                      0
# net_weight                                                             0
# unit                                                                  KG
# audit_status                                                           A
# audit_date                                                             0
# audit_userid                                                           0
# material_description_f                                       BALED EMPTY
# package_date_f                                       2019-05-31 15:34:00
# time_delta_f                                                           0
# standard_weight_f                                                      0
#
#                                                                        8  \
# Unnamed: 0                                                            90
# DeviceType                                                         Baler
# id                                                                     0
# img_url                                                                0
# package_date                                         2020-04-28 17:52:00
# device_id                           0cf08389-c413-46b8-b260-2b2d2d94778d
# DeviceCode                                                             0
# package_id                                                             0
# barcode                                                                0
# material_type                                                          0
# material_description_from_original                                     0
# ir_original_class                                                      0
# net_weight                                                             0
# unit                                                                  KG
# audit_status                                                           A
# audit_date                                                             0
# audit_userid                                                           0
# material_description_f                                       BALED EMPTY
# package_date_f                                       2020-04-28 17:52:00
# time_delta_f                                                           0
# standard_weight_f                                                      0
#
#                                                                        9
# Unnamed: 0                                                            91
# DeviceType                                                         Baler
# id                                                                     0
# img_url                                                                0
# package_date                                         2020-06-24 10:17:00
# device_id                           0d4af338-80b8-49eb-a0e4-dc074deebc3b
# DeviceCode                                                             0
# package_id                                                             0
# barcode                                                                0
# material_type                                                          0
# material_description_from_original                                     0
# ir_original_class                                                      0
# net_weight                                                             0
# unit                                                                  KG
# audit_status                                                           A
# audit_date                                                             0
# audit_userid                                                           0
# material_description_f                                       BALED EMPTY
# package_date_f                                       2020-06-24 10:17:00
# time_delta_f                                                           0
# standard_weight_f                                                      0

# %% [markdown]
# ## barcode to label

# %%
# How many barcode are duplicated?

df['barcode'].value_counts()[0:5]
# Out:
# 0                               203
# WALM10182006260A035903590603      1
# WALM10042006260A041204120991      1
# SYSC10022006260A063706370082      1
# AMZS10172006260A083008300017      1
# Name: barcode, dtype: int64

# %%
# Create an aditional field that contains if the bale has a barcode or not.
df['barcode_f'] = np.where(df['barcode'] == 'null', 0, df['barcode'])

# %%
df['label_f'] = np.where(df['barcode_f'] == 0, 0, 1)

# %%
df[df['barcode'] == 'null']['label_f'].unique()
# Out:
# array([], dtype=int32)

# %%
df['label_f'].value_counts()
# Out:
# 0    203
# 1     59
# Name: label_f, dtype: int64

# %% [markdown]
# ## img_url to image

# %%
# create an aditional field that contains if the bale has a image or not.
df['img_url'].value_counts()
# Out:
# 0                                       187
# 34676e99-912b-4397-a176-802d63cb2961      1
# 283793d6-223e-462b-9561-d84ef1eb48c7      1
# 8d401286-34c5-4370-894a-fdacfcf6c7d8      1
# c1a5109b-18a7-49db-844a-c26ac257ebcd      1
#                                        ...
# 8f2392f9-898d-4f56-ade6-8a2cb79f7146      1
# e05fb96c-fbc9-4bbb-ac50-6d37cd61d57b      1
# d7a61856-787e-47d9-b161-ceca6b188750      1
# c84b91ad-8529-443a-b165-a86161bfb163      1
# 7e45024a-b0c7-4d10-a78c-a77f4ac21159      1
# Name: img_url, Length: 76, dtype: int64

# %%
df['image_f'] = np.where(df['img_url'] == 0, 0, 1)

# %%
df['image_f'].value_counts()
# Out:
# 0    187
# 1     75
# Name: image_f, dtype: int64

# %% [markdown]
# ## duplicates in manual audit

# %%
# Duplicates are marked from zero to one
df['audit_duplicates_f'] = df.groupby(by=['device_id'])['time_delta_f'].shift(-1, fill_value=60)
df['audit_duplicates_f'] = np.where(df['audit_duplicates_f'] <= 5, 0, 1)

# %%
df[df['audit_duplicates_f'] == 0].head(10).T
# Out:
#                                                                      17   \
# Unnamed: 0                                                            71
# DeviceType                                                         Baler
# id                                  c84b91ad-8529-443a-b165-a86161bfb163
# img_url                             c84b91ad-8529-443a-b165-a86161bfb163
# package_date                                         2020-06-26 15:01:00
# device_id                           175ded97-27a5-4c71-b084-2dccaa759b8c
# DeviceCode                                                      SYSC1002
# package_id                                                            79
# barcode                                     SYSC10022006260A064206420079
# material_type                                                          A
# material_description_from_original                             OCC BALED
# ir_original_class                                                      0
# net_weight                                                           642
# unit                                                                  LB
# audit_status                                                           0
# audit_date                                                             0
# audit_userid                                                           0
# material_description_f                                   BALED CARDBOARD
# package_date_f                                       2020-06-26 15:01:00
# time_delta_f                                                        2183
# standard_weight_f                                                    291
# barcode_f                                   SYSC10022006260A064206420079
# label_f                                                                1
# image_f                                                                1
# audit_duplicates_f                                                     0
#
#                                                                      19   \
# Unnamed: 0                                                            20
# DeviceType                                                         Baler
# id                                  3dd68889-d79b-4081-b1f5-95096982efac
# img_url                             3dd68889-d79b-4081-b1f5-95096982efac
# package_date                                         2020-06-26 15:20:00
# device_id                           175ded97-27a5-4c71-b084-2dccaa759b8c
# DeviceCode                                                      SYSC1002
# package_id                                                            81
# barcode                                     SYSC10022006260A062306230081
# material_type                                                          A
# material_description_from_original                             OCC BALED
# ir_original_class                                                      0
# net_weight                                                           623
# unit                                                                  LB
# audit_status                                                           0
# audit_date                                                             0
# audit_userid                                                           0
# material_description_f                                   BALED CARDBOARD
# package_date_f                                       2020-06-26 15:20:00
# time_delta_f                                                          14
# standard_weight_f                                                    283
# barcode_f                                   SYSC10022006260A062306230081
# label_f                                                                1
# image_f                                                                1
# audit_duplicates_f                                                     0
#
#                                                                      20   \
# Unnamed: 0                                                             8
# DeviceType                                                         Baler
# id                                  1c817bdb-3433-4d74-b317-fb726cefdfe5
# img_url                             1c817bdb-3433-4d74-b317-fb726cefdfe5
# package_date                                         2020-06-26 15:24:00
# device_id                           175ded97-27a5-4c71-b084-2dccaa759b8c
# DeviceCode                                                      SYSC1002
# package_id                                                            82
# barcode                                     SYSC10022006260A063706370082
# material_type                                                          A
# material_description_from_original                             OCC BALED
# ir_original_class                                                      0
# net_weight                                                           637
# unit                                                                  LB
# audit_status                                                           0
# audit_date                                                             0
# audit_userid                                                           0
# material_description_f                                   BALED CARDBOARD
# package_date_f                                       2020-06-26 15:24:00
# time_delta_f                                                           4
# standard_weight_f                                                    289
# barcode_f                                   SYSC10022006260A063706370082
# label_f                                                                1
# image_f                                                                1
# audit_duplicates_f                                                     0
#
#                                                                      21   \
# Unnamed: 0                                                            64
# DeviceType                                                         Baler
# id                                  b8c19c00-a748-45db-88f9-8be71b39dff0
# img_url                             b8c19c00-a748-45db-88f9-8be71b39dff0
# package_date                                         2020-06-26 15:24:00
# device_id                           175ded97-27a5-4c71-b084-2dccaa759b8c
# DeviceCode                                                      SYSC1002
# package_id                                                            83
# barcode                                     SYSC10022006260A062206220083
# material_type                                                          A
# material_description_from_original                             OCC BALED
# ir_original_class                                                      0
# net_weight                                                           622
# unit                                                                  LB
# audit_status                                                           0
# audit_date                                                             0
# audit_userid                                                           0
# material_description_f                                   BALED CARDBOARD
# package_date_f                                       2020-06-26 15:24:00
# time_delta_f                                                           0
# standard_weight_f                                                    282
# barcode_f                                   SYSC10022006260A062206220083
# label_f                                                                1
# image_f                                                                1
# audit_duplicates_f                                                     0
#
#                                                                      25   \
# Unnamed: 0                                                            62
# DeviceType                                                         Baler
# id                                  b4721650-8585-4200-b22b-1741f2b81035
# img_url                             b4721650-8585-4200-b22b-1741f2b81035
# package_date                                         2020-06-26 15:48:00
# device_id                           175ded97-27a5-4c71-b084-2dccaa759b8c
# DeviceCode                                                      SYSC1002
# package_id                                                            87
# barcode                                     SYSC10022006260A061806180087
# material_type                                                          A
# material_description_from_original                             OCC BALED
# ir_original_class                                                      0
# net_weight                                                           618
# unit                                                                  LB
# audit_status                                                           0
# audit_date                                                             0
# audit_userid                                                           0
# material_description_f                                   BALED CARDBOARD
# package_date_f                                       2020-06-26 15:48:00
# time_delta_f                                                           9
# standard_weight_f                                                    280
# barcode_f                                   SYSC10022006260A061806180087
# label_f                                                                1
# image_f                                                                1
# audit_duplicates_f                                                     0
#
#                                                                      90   \
# Unnamed: 0                                                            34
# DeviceType                                                         Baler
# id                                  6b83edb2-d5f3-4409-8286-681e2eaf437a
# img_url                             6b83edb2-d5f3-4409-8286-681e2eaf437a
# package_date                                         2020-06-26 10:28:00
# device_id                           668c00d2-b89d-49a7-b8f6-685f089ee329
# DeviceCode                                                      FETX1003
# package_id                                                           222
# barcode                                     FETX10032006260A077007700222
# material_type                                                          A
# material_description_from_original                                   OCC
# ir_original_class                                        BALED CARDBOARD
# net_weight                                                           770
# unit                                                                  LB
# audit_status                                                           0
# audit_date                                                             0
# audit_userid                                                           0
# material_description_f                                   BALED CARDBOARD
# package_date_f                                       2020-06-26 10:28:00
# time_delta_f                                                        2194
# standard_weight_f                                                    349
# barcode_f                                   FETX10032006260A077007700222
# label_f                                                                1
# image_f                                                                1
# audit_duplicates_f                                                     0
#
#                                                                      99   \
# Unnamed: 0                                                            76
# DeviceType                                                         Baler
# id                                  e942fbed-bbcf-4484-8f2e-5c4e4c51eb27
# img_url                             e942fbed-bbcf-4484-8f2e-5c4e4c51eb27
# package_date                                         2020-06-26 09:38:00
# device_id                           6ae02536-9609-4668-8eca-7fd9b98135ca
# DeviceCode                                                      LEYM1003
# package_id                                                          2542
# barcode                                                                0
# material_type                                                          A
# material_description_from_original                                CARTON
# ir_original_class                                        BALED CARDBOARD
# net_weight                                                            93
# unit                                                                  KG
# audit_status                                                           0
# audit_date                                                             0
# audit_userid                                                           0
# material_description_f                                   BALED CARDBOARD
# package_date_f                                       2020-06-26 09:38:00
# time_delta_f                                                         226
# standard_weight_f                                                     93
# barcode_f                                                              0
# label_f                                                                0
# image_f                                                                1
# audit_duplicates_f                                                     0
#
#                                                                      111  \
# Unnamed: 0                                                            13
# DeviceType                                                         Baler
# id                                  2dd67cc1-9323-4dc1-af7a-29cda1a8b148
# img_url                                                                0
# package_date                                         2020-06-26 09:52:00
# device_id                           7849428d-2323-408b-81a0-9048d573841e
# DeviceCode                                                      HFCC1001
# package_id                                                           438
# barcode                                     HFCC10012006260A025002500438
# material_type                                                          A
# material_description_from_original                                  FILM
# ir_original_class                                             BALED FILM
# net_weight                                                           250
# unit                                                                  LB
# audit_status                                                           0
# audit_date                                                             0
# audit_userid                                                           0
# material_description_f                                        BALED FILM
# package_date_f                                       2020-06-26 09:52:00
# time_delta_f                                                         263
# standard_weight_f                                                    113
# barcode_f                                   HFCC10012006260A025002500438
# label_f                                                                1
# image_f                                                                0
# audit_duplicates_f                                                     0
#
#                                                                      112  \
# Unnamed: 0                                                            70
# DeviceType                                                         Baler
# id                                  c6f106eb-7546-4021-9a6c-555aafc16941
# img_url                                                                0
# package_date                                         2020-06-26 09:53:00
# device_id                           7849428d-2323-408b-81a0-9048d573841e
# DeviceCode                                                      HFCC1001
# package_id                                                           439
# barcode                                     HFCC10012006260A025002500439
# material_type                                                          A
# material_description_from_original                                  FILM
# ir_original_class                                             BALED FILM
# net_weight                                                           250
# unit                                                                  LB
# audit_status                                                           0
# audit_date                                                             0
# audit_userid                                                           0
# material_description_f                                        BALED FILM
# package_date_f                                       2020-06-26 09:53:00
# time_delta_f                                                           1
# standard_weight_f                                                    113
# barcode_f                                   HFCC10012006260A025002500439
# label_f                                                                1
# image_f                                                                0
# audit_duplicates_f                                                     0
#
#                                                                      113
# Unnamed: 0                                                            36
# DeviceType                                                         Baler
# id                                  7318b1cc-139d-48b0-884d-d0522d98b439
# img_url                                                                0
# package_date                                         2020-06-26 09:54:00
# device_id                           7849428d-2323-408b-81a0-9048d573841e
# DeviceCode                                                      HFCC1001
# package_id                                                           441
# barcode                                     HFCC10012006260A025002500441
# material_type                                                          A
# material_description_from_original                                  FILM
# ir_original_class                                             BALED FILM
# net_weight                                                           250
# unit                                                                  LB
# audit_status                                                           0
# audit_date                                                             0
# audit_userid                                                           0
# material_description_f                                        BALED FILM
# package_date_f                                       2020-06-26 09:54:00
# time_delta_f                                                           1
# standard_weight_f                                                    113
# barcode_f                                   HFCC10012006260A025002500441
# label_f                                                                1
# image_f                                                                0
# audit_duplicates_f                                                     0

# %%
df[df['device_id'] == '668c00d2-b89d-49a7-b8f6-685f089ee329'].T
# Out:
#                                                                       89  \
# Unnamed: 0                                                           153
# DeviceType                                                         Baler
# id                                                                     0
# img_url                                                                0
# package_date                                         2020-06-24 21:54:00
# device_id                           668c00d2-b89d-49a7-b8f6-685f089ee329
# DeviceCode                                                             0
# package_id                                                             0
# barcode                                                                0
# material_type                                                          0
# material_description_from_original                                     0
# ir_original_class                                                      0
# net_weight                                                             0
# unit                                                                  KG
# audit_status                                                           A
# audit_date                                                             0
# audit_userid                                                           0
# material_description_f                                       BALED EMPTY
# package_date_f                                       2020-06-24 21:54:00
# time_delta_f                                                           0
# standard_weight_f                                                      0
# barcode_f                                                              0
# label_f                                                                0
# image_f                                                                0
# audit_duplicates_f                                                     1
#
#                                                                       90  \
# Unnamed: 0                                                            34
# DeviceType                                                         Baler
# id                                  6b83edb2-d5f3-4409-8286-681e2eaf437a
# img_url                             6b83edb2-d5f3-4409-8286-681e2eaf437a
# package_date                                         2020-06-26 10:28:00
# device_id                           668c00d2-b89d-49a7-b8f6-685f089ee329
# DeviceCode                                                      FETX1003
# package_id                                                           222
# barcode                                     FETX10032006260A077007700222
# material_type                                                          A
# material_description_from_original                                   OCC
# ir_original_class                                        BALED CARDBOARD
# net_weight                                                           770
# unit                                                                  LB
# audit_status                                                           0
# audit_date                                                             0
# audit_userid                                                           0
# material_description_f                                   BALED CARDBOARD
# package_date_f                                       2020-06-26 10:28:00
# time_delta_f                                                        2194
# standard_weight_f                                                    349
# barcode_f                                   FETX10032006260A077007700222
# label_f                                                                1
# image_f                                                                1
# audit_duplicates_f                                                     0
#
#                                                                       91
# Unnamed: 0                                                            73
# DeviceType                                                         Baler
# id                                  d7a61856-787e-47d9-b161-ceca6b188750
# img_url                             d7a61856-787e-47d9-b161-ceca6b188750
# package_date                                         2020-06-26 10:28:00
# device_id                           668c00d2-b89d-49a7-b8f6-685f089ee329
# DeviceCode                                                      FETX1003
# package_id                                                           223
# barcode                                     FETX10032006260A077507750223
# material_type                                                          A
# material_description_from_original                                   OCC
# ir_original_class                                        BALED CARDBOARD
# net_weight                                                           775
# unit                                                                  LB
# audit_status                                                           0
# audit_date                                                             0
# audit_userid                                                           0
# material_description_f                                   BALED CARDBOARD
# package_date_f                                       2020-06-26 10:28:00
# time_delta_f                                                           0
# standard_weight_f                                                    352
# barcode_f                                   FETX10032006260A077507750223
# label_f                                                                1
# image_f                                                                1
# audit_duplicates_f                                                     1

# %% [markdown]
# ## mark group of duplicates

# %%
df['duplicates'] = df.groupby(by=['device_id'])['audit_duplicates_f'].diff(1).fillna(0)
df['duplicates'].unique()
# Out:
# array([ 0., -1.,  1.])

# %%
df[df['device_id'] == '668c00d2-b89d-49a7-b8f6-685f089ee329'].T
# Out:
#                                                                       89  \
# Unnamed: 0                                                           153
# DeviceType                                                         Baler
# id                                                                     0
# img_url                                                                0
# package_date                                         2020-06-24 21:54:00
# device_id                           668c00d2-b89d-49a7-b8f6-685f089ee329
# DeviceCode                                                             0
# package_id                                                             0
# barcode                                                                0
# material_type                                                          0
# material_description_from_original                                     0
# ir_original_class                                                      0
# net_weight                                                             0
# unit                                                                  KG
# audit_status                                                           A
# audit_date                                                             0
# audit_userid                                                           0
# material_description_f                                       BALED EMPTY
# package_date_f                                       2020-06-24 21:54:00
# time_delta_f                                                           0
# standard_weight_f                                                      0
# barcode_f                                                              0
# label_f                                                                0
# image_f                                                                0
# audit_duplicates_f                                                     1
# duplicates                                                             0
#
#                                                                       90  \
# Unnamed: 0                                                            34
# DeviceType                                                         Baler
# id                                  6b83edb2-d5f3-4409-8286-681e2eaf437a
# img_url                             6b83edb2-d5f3-4409-8286-681e2eaf437a
# package_date                                         2020-06-26 10:28:00
# device_id                           668c00d2-b89d-49a7-b8f6-685f089ee329
# DeviceCode                                                      FETX1003
# package_id                                                           222
# barcode                                     FETX10032006260A077007700222
# material_type                                                          A
# material_description_from_original                                   OCC
# ir_original_class                                        BALED CARDBOARD
# net_weight                                                           770
# unit                                                                  LB
# audit_status                                                           0
# audit_date                                                             0
# audit_userid                                                           0
# material_description_f                                   BALED CARDBOARD
# package_date_f                                       2020-06-26 10:28:00
# time_delta_f                                                        2194
# standard_weight_f                                                    349
# barcode_f                                   FETX10032006260A077007700222
# label_f                                                                1
# image_f                                                                1
# audit_duplicates_f                                                     0
# duplicates                                                            -1
#
#                                                                       91
# Unnamed: 0                                                            73
# DeviceType                                                         Baler
# id                                  d7a61856-787e-47d9-b161-ceca6b188750
# img_url                             d7a61856-787e-47d9-b161-ceca6b188750
# package_date                                         2020-06-26 10:28:00
# device_id                           668c00d2-b89d-49a7-b8f6-685f089ee329
# DeviceCode                                                      FETX1003
# package_id                                                           223
# barcode                                     FETX10032006260A077507750223
# material_type                                                          A
# material_description_from_original                                   OCC
# ir_original_class                                        BALED CARDBOARD
# net_weight                                                           775
# unit                                                                  LB
# audit_status                                                           0
# audit_date                                                             0
# audit_userid                                                           0
# material_description_f                                   BALED CARDBOARD
# package_date_f                                       2020-06-26 10:28:00
# time_delta_f                                                           0
# standard_weight_f                                                    352
# barcode_f                                   FETX10032006260A077507750223
# label_f                                                                1
# image_f                                                                1
# audit_duplicates_f                                                     1
# duplicates                                                             1

# %%
df['duplicates'] = np.where(df['audit_duplicates_f'] == 0, 1, df['duplicates']).astype(int)
df['duplicates'].unique()
# Out:
# array([0, 1])

# %%
df[df['device_id'] == '668c00d2-b89d-49a7-b8f6-685f089ee329'].T
# Out:
#                                                                       89  \
# Unnamed: 0                                                           153
# DeviceType                                                         Baler
# id                                                                     0
# img_url                                                                0
# package_date                                         2020-06-24 21:54:00
# device_id                           668c00d2-b89d-49a7-b8f6-685f089ee329
# DeviceCode                                                             0
# package_id                                                             0
# barcode                                                                0
# material_type                                                          0
# material_description_from_original                                     0
# ir_original_class                                                      0
# net_weight                                                             0
# unit                                                                  KG
# audit_status                                                           A
# audit_date                                                             0
# audit_userid                                                           0
# material_description_f                                       BALED EMPTY
# package_date_f                                       2020-06-24 21:54:00
# time_delta_f                                                           0
# standard_weight_f                                                      0
# barcode_f                                                              0
# label_f                                                                0
# image_f                                                                0
# audit_duplicates_f                                                     1
# duplicates                                                             0
#
#                                                                       90  \
# Unnamed: 0                                                            34
# DeviceType                                                         Baler
# id                                  6b83edb2-d5f3-4409-8286-681e2eaf437a
# img_url                             6b83edb2-d5f3-4409-8286-681e2eaf437a
# package_date                                         2020-06-26 10:28:00
# device_id                           668c00d2-b89d-49a7-b8f6-685f089ee329
# DeviceCode                                                      FETX1003
# package_id                                                           222
# barcode                                     FETX10032006260A077007700222
# material_type                                                          A
# material_description_from_original                                   OCC
# ir_original_class                                        BALED CARDBOARD
# net_weight                                                           770
# unit                                                                  LB
# audit_status                                                           0
# audit_date                                                             0
# audit_userid                                                           0
# material_description_f                                   BALED CARDBOARD
# package_date_f                                       2020-06-26 10:28:00
# time_delta_f                                                        2194
# standard_weight_f                                                    349
# barcode_f                                   FETX10032006260A077007700222
# label_f                                                                1
# image_f                                                                1
# audit_duplicates_f                                                     0
# duplicates                                                             1
#
#                                                                       91
# Unnamed: 0                                                            73
# DeviceType                                                         Baler
# id                                  d7a61856-787e-47d9-b161-ceca6b188750
# img_url                             d7a61856-787e-47d9-b161-ceca6b188750
# package_date                                         2020-06-26 10:28:00
# device_id                           668c00d2-b89d-49a7-b8f6-685f089ee329
# DeviceCode                                                      FETX1003
# package_id                                                           223
# barcode                                     FETX10032006260A077507750223
# material_type                                                          A
# material_description_from_original                                   OCC
# ir_original_class                                        BALED CARDBOARD
# net_weight                                                           775
# unit                                                                  LB
# audit_status                                                           0
# audit_date                                                             0
# audit_userid                                                           0
# material_description_f                                   BALED CARDBOARD
# package_date_f                                       2020-06-26 10:28:00
# time_delta_f                                                           0
# standard_weight_f                                                    352
# barcode_f                                   FETX10032006260A077507750223
# label_f                                                                1
# image_f                                                                1
# audit_duplicates_f                                                     1
# duplicates                                                             1

# %%
df.drop(df[df['audit_status'] == 'A'].index, inplace=True)

# %%
df.shape
# Out:
# (85, 26)

# %% [markdown]
# ## audit result of the group of duplicates

# %%
def find_reperead_groups(temp_df):
    print(temp_df['device_id'].unique())
    
    group_flag = False

    lower_pointer = 0
    upper_pointer = 0

    for i in range(len(temp_df)):

        if temp_df['audit_duplicates_f'].iloc[i] == 0:

            if group_flag == False:
                group_flag = True
                lower_pointer = i

        else:
            if group_flag == True:
                group_flag = False
                upper_pointer = i
                
                audit_lst = list(temp_df[lower_pointer:upper_pointer+1]['audit_status'])

                print('lower_pointer', lower_pointer, ': upper_pointer', upper_pointer)
                print(temp_df[lower_pointer:upper_pointer+1][['id','audit_status','package_date_f','time_delta_f']])
                        
    return temp_df

# %%
df = df.groupby(by=['device_id']).apply(find_reperead_groups)
# Out:
# ['04152770-fbc7-41a8-9b61-b19eaf55dc8f']
# ['09d09144-5db2-4461-8706-2f74b06e52b8']
# ['15da27b8-81d2-4944-8479-b1a2445c0d2a']
# ['175ded97-27a5-4c71-b084-2dccaa759b8c']
# lower_pointer 0 : upper_pointer 1
#                                       id audit_status      package_date_f  \
# 17  c84b91ad-8529-443a-b165-a86161bfb163            0 2020-06-26 15:01:00
# 18  4963a19c-3968-43b2-a19e-bc4055a7cca5            0 2020-06-26 15:06:00
#
#     time_delta_f
# 17          2183
# 18             5
# lower_pointer 2 : upper_pointer 5
#                                       id audit_status      package_date_f  \
# 19  3dd68889-d79b-4081-b1f5-95096982efac            0 2020-06-26 15:20:00
# 20  1c817bdb-3433-4d74-b317-fb726cefdfe5            0 2020-06-26 15:24:00
# 21  b8c19c00-a748-45db-88f9-8be71b39dff0            0 2020-06-26 15:24:00
# 22  b1926e91-ea27-4281-9aac-3f3c6324fdc8            0 2020-06-26 15:26:00
#
#     time_delta_f
# 19            14
# 20             4
# 21             0
# 22             2
# lower_pointer 8 : upper_pointer 9
#                                       id audit_status      package_date_f  \
# 25  b4721650-8585-4200-b22b-1741f2b81035            0 2020-06-26 15:48:00
# 26  7e45024a-b0c7-4d10-a78c-a77f4ac21159            0 2020-06-26 15:49:00
#
#     time_delta_f
# 25             9
# 26             1
# ['1efbf09a-ed33-4fbd-8219-d390903e5a42']
# ['265eecdc-f00f-4af1-b4f9-f735e14de82d']
# ['36464b5e-ae31-4de9-a74d-36d6c3b117f1']
# ['37d58b69-7c42-4261-9805-0fa2edb96273']
# ['3e9a4460-7218-40f8-9572-e20008795361']
# ['515e0fb6-0a4e-49be-9c5d-d3f3102bd141']
# ['55d6c2f7-fa6e-4c0f-a6f6-70782981690b']
# ['668c00d2-b89d-49a7-b8f6-685f089ee329']
# lower_pointer 0 : upper_pointer 1
#                                       id audit_status      package_date_f  \
# 90  6b83edb2-d5f3-4409-8286-681e2eaf437a            0 2020-06-26 10:28:00
# 91  d7a61856-787e-47d9-b161-ceca6b188750            0 2020-06-26 10:28:00
#
#     time_delta_f
# 90          2194
# 91             0
# ['6ae02536-9609-4668-8eca-7fd9b98135ca']
# lower_pointer 2 : upper_pointer 3
#                                        id audit_status      package_date_f  \
# 99   e942fbed-bbcf-4484-8f2e-5c4e4c51eb27            0 2020-06-26 09:38:00
# 100  22fc8abb-3b57-4921-86d6-ee320876247e            0 2020-06-26 09:40:00
#
#      time_delta_f
# 99            226
# 100             2
# ['6b0dbef3-eaee-4f7b-9c41-cdb4edade13e']
# ['72125237-1be4-46c2-96af-26adff920c66']
# ['7849428d-2323-408b-81a0-9048d573841e']
# lower_pointer 2 : upper_pointer 7
#                                        id audit_status      package_date_f  \
# 111  2dd67cc1-9323-4dc1-af7a-29cda1a8b148            0 2020-06-26 09:52:00
# 112  c6f106eb-7546-4021-9a6c-555aafc16941            0 2020-06-26 09:53:00
# 113  7318b1cc-139d-48b0-884d-d0522d98b439            0 2020-06-26 09:54:00
# 114  b1a17245-d567-41d6-9d4a-214bc8e31437            0 2020-06-26 09:54:00
# 115  8927ddf7-9626-4817-b17e-ddf9fcb4b24f            0 2020-06-26 09:55:00
# 116  b3efdeb8-61ce-45ae-bb69-2415947a16a2            0 2020-06-26 09:55:00
#
#      time_delta_f
# 111           263
# 112             1
# 113             1
# 114             0
# 115             1
# 116             0
# ['7b111958-f1d3-4b15-a169-be6b138bcba0']
# ['80612f88-1859-4c7d-b2e0-354a2ee5fc29']
# lower_pointer 0 : upper_pointer 1
#                                        id audit_status      package_date_f  \
# 121  2b609832-c78a-4436-9402-dc78000c9a21            0 2020-06-26 10:09:00
# 122  7e5625d2-a77f-4af2-bcd8-20a4890d3004            0 2020-06-26 10:10:00
#
#      time_delta_f
# 121          4203
# 122             1
# ['817631f2-66c6-47c5-82a7-90ab8e023dae']
# ['84fde9c4-43fc-4e65-9ed4-52f7d50d8e4c']
# ['8a1bf975-8106-4833-bde4-1d1fea9d2897']
# ['9f76a584-b71c-4e26-a2fc-1938618ea34c']
# ['9f9d9af3-62be-456a-b5d6-1fbee6ae773d']
# ['a15159b7-ea8e-4821-98fa-7e915662ce83']
# ['a6fe2bcc-c031-439b-a89a-604b3e979aa8']
# ['ae37f11a-3b99-4f63-9f83-e90b7980d244']
# ['b9e48ef9-1a7b-41c2-bad4-3c70ac2b14e9']
# ['bfd582e7-322b-465f-83c8-3e56b0085e31']
# ['cd2b1dd2-934c-4abe-95d4-d7a3f97e5377']
# ['d29cbd50-1f14-4c2d-b40a-61e5363791a2']
# ['d6a92243-6e95-4678-ac07-15b51ab71546']
# ['da28f0b0-1d03-43e8-90c6-5029576f6af7']
# ['df7f898b-c934-49a1-891f-b7eb92967093']
# ['e9a56321-fefa-4a03-a263-2b6728e29a49']
# ['f8f125a4-c03c-4f45-994a-7f99175dfeb5']
# ['f9165f5d-335c-40d6-8ee3-9e6ef7cc4bbf']
# ['fc7dacf9-8960-4a88-b4a9-02c36b6df9e0']

# %%
df.head(3).T
# Out:
#                                                                        3  \
# Unnamed: 0                                                            28
# DeviceType                                                         Baler
# id                                  56016431-4754-4155-a88e-34025a996b0a
# img_url                             56016431-4754-4155-a88e-34025a996b0a
# package_date                                         2020-06-26 10:39:00
# device_id                           04152770-fbc7-41a8-9b61-b19eaf55dc8f
# DeviceCode                                                      WALM1018
# package_id                                                           604
# barcode                                     WALM10182006260B011201120604
# material_type                                                          B
# material_description_from_original                                 PLAYO
# ir_original_class                                             BALED FILM
# net_weight                                                           112
# unit                                                                  KG
# audit_status                                                           0
# audit_date                                                             0
# audit_userid                                                           0
# material_description_f                                        BALED FILM
# package_date_f                                       2020-06-26 10:39:00
# time_delta_f                                                        1266
# standard_weight_f                                                    112
# barcode_f                                   WALM10182006260B011201120604
# label_f                                                                1
# image_f                                                                1
# audit_duplicates_f                                                     1
# duplicates                                                             0
#
#                                                                        4  \
# Unnamed: 0                                                            83
# DeviceType                                                         Baler
# id                                  fe5cddc7-303e-4a04-a909-337cc23e9f23
# img_url                             fe5cddc7-303e-4a04-a909-337cc23e9f23
# package_date                                         2020-06-26 09:50:00
# device_id                           04152770-fbc7-41a8-9b61-b19eaf55dc8f
# DeviceCode                                                      WALM1018
# package_id                                                           603
# barcode                                     WALM10182006260A035903590603
# material_type                                                          A
# material_description_from_original                                CARTON
# ir_original_class                                        BALED CARDBOARD
# net_weight                                                           359
# unit                                                                  KG
# audit_status                                                           0
# audit_date                                                             0
# audit_userid                                                           0
# material_description_f                                   BALED CARDBOARD
# package_date_f                                       2020-06-26 09:50:00
# time_delta_f                                                          49
# standard_weight_f                                                    359
# barcode_f                                   WALM10182006260A035903590603
# label_f                                                                1
# image_f                                                                1
# audit_duplicates_f                                                     1
# duplicates                                                             0
#
#                                                                        6
# Unnamed: 0                                                            23
# DeviceType                                                         Baler
# id                                  48fa2e14-0fde-4b83-99c6-592287781f1b
# img_url                             48fa2e14-0fde-4b83-99c6-592287781f1b
# package_date                                         2020-06-26 11:15:00
# device_id                           09d09144-5db2-4461-8706-2f74b06e52b8
# DeviceCode                                                      LEYM1008
# package_id                                                           539
# barcode                                                                0
# material_type                                                          A
# material_description_from_original                                CARTON
# ir_original_class                                        BALED CARDBOARD
# net_weight                                                           256
# unit                                                                  KG
# audit_status                                                           0
# audit_date                                                             0
# audit_userid                                                           0
# material_description_f                                   BALED CARDBOARD
# package_date_f                                       2020-06-26 11:15:00
# time_delta_f                                                        1547
# standard_weight_f                                                    256
# barcode_f                                                              0
# label_f                                                                0
# image_f                                                                1
# audit_duplicates_f                                                     1
# duplicates                                                             0

# %%
df['ir_original_class'] = np.where(df['ir_original_class'] == 'None', 'BALED EMPTY', df['ir_original_class'])
df['ir_original_class'] = np.where(df['ir_original_class'] == 0, 'BALED EMPTY', df['ir_original_class'])
df['ir_original_class'] = np.where(df['ir_original_class'] == 'BALED PLASTIC', 'BALED EMPTY', df['ir_original_class'])
df['ir_original_class'] = np.where(df['ir_original_class'] == 'BALED FOAM', 'BALED EMPTY', df['ir_original_class'])
df['ir_original_class'] = np.where(df['ir_original_class'] == 'BALED PET', 'BALED EMPTY', df['ir_original_class'])
df['ir_original_class'] = np.where(df['ir_original_class'] == 'BALED SHRINK', 'BALED EMPTY', df['ir_original_class'])
df['ir_original_class'] = np.where(df['ir_original_class'] == 'BALED ALUMINUM', 'BALED EMPTY', df['ir_original_class'])

# %% [markdown]
# ## Feature selection

# %%
df_src = df[['device_id',
             'id',
             'label_f',
             'image_f',
             'time_delta_f',
             'standard_weight_f',
             'material_description_f',
             'ir_original_class',
             'duplicates']]

# %%
df_model = pd.get_dummies(df_src, columns=["material_description_f","ir_original_class"], drop_first=False)

# %%
df_model.columns
# Out:
# Index(['device_id', 'id', 'label_f', 'image_f', 'time_delta_f',
#        'standard_weight_f', 'duplicates',
#        'material_description_f_BALED CARDBOARD',
#        'material_description_f_BALED EMPTY',
#        'material_description_f_BALED FILM',
#        'ir_original_class_BALED CARDBOARD', 'ir_original_class_BALED EMPTY',
#        'ir_original_class_BALED FILM'],
#       dtype='object')

# %% [markdown]
# ## One Hot Encoding

# %%
#df_model.drop(columns=['material_description_f_BALED EMPTY'], inplace=True)
df_model.drop(columns=['material_description_f_BALED EMPTY','ir_original_class_BALED EMPTY'], inplace=True)

# %%
#df_model[(df_model['audit_status_f'] == 'A') & (df_model['material_description_f_BALED CARDBOARD'] == 1)].head(21).T

# %%
df_model.to_csv('data_frame_to_model.csv', index_label=False)

# %% [markdown]
# # Split data in Training and Validation Sets

# %%
# Define the X and Y variables
X = df_model[['label_f',
              'image_f',
              'time_delta_w',
              'standard_weight_w',
              'material_description_f_BALED CARDBOARD',
              'material_description_f_BALED FILM',
              'ir_original_class_BALED CARDBOARD',
              'ir_original_class_BALED FILM'
             #'duplicates'
             ]]

y = df_model['audit_status_f'] # binary output
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-98-2bd29134a405> in <module>
#       7               'material_description_f_BALED FILM',
#       8               'ir_original_class_BALED CARDBOARD',
# ----> 9               'ir_original_class_BALED FILM'
#      10              #'duplicates'
#      11              ]]
#
# ~\AppData\Local\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2804             if is_iterator(key):
#    2805                 key = list(key)
# -> 2806             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2807
#    2808         # take() does not accept boolean indexers
#
# ~\AppData\Local\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1551
#    1552         self._validate_read_indexer(
# -> 1553             keyarr, indexer, o._get_axis_number(axis), raise_missing=raise_missing
#    1554         )
#    1555         return keyarr, indexer
#
# ~\AppData\Local\anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1644             if not (self.name == "loc" and not raise_missing):
#    1645                 not_found = list(set(key) - set(ax))
# -> 1646                 raise KeyError(f"{not_found} not in index")
#    1647
#    1648             # we skip the warning on Categorical/Interval
#
# KeyError: "['standard_weight_w', 'time_delta_w'] not in index"

# %%
import pickle

# %%
pickle_out = open('baler_classifier.pkl','wb')
pickle.dump(rfc2, pickle_out)
pickle_out.close()
